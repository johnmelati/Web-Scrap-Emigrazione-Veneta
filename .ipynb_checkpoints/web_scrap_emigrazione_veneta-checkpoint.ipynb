# %%
#url: http://www.emigrazioneveneta.com/

# %%
## BIBLIOTECAS:
    # pip install requests2
    # pip install pandas
    # pip install lxml
    # pip install beautifulsoup4
    # pip install selenium

import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options
import os
import datetime
import time
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import string

time1=datetime.datetime.now()

# %%
def build_driver(download_path): 
    
    '''
    Esta função inicializa o webdriver incluindo as preferências.
    
    args:
    download_path: diretório da pasta de download.
    
    '''

    print("Ligando o Chrome Remoto...")
    option = Options()
    option.headless = True
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized") #Maximizar
    prefs = {"profile.default_content_settings.popups": 0,
             "download.default_directory": download_path, # Importante-Finalizar com barra dupla
             "download.prompt_for_download": False,
             "directory_upgrade": True,
             "safebrowsing.enabled": True}
    options.add_experimental_option("prefs", prefs)
    #driver=webdriver.Firefox()
    #driver = webdriver.Chrome(options=options)
    driver = webdriver.Chrome(r"C:\Users\John Melati\Documents\GitHub\web_scraping_emigrazione_veneta\chromedriver.exe", options=options)
    print("Ok")
    return driver

def login(driver, url_login): 
    
    '''
    Esta função realiza o login no site.
    
    args:
    driver: webdriver.
    url_login: url do site.
    
    '''

    print("Entrando na página de login...")
    driver.get(url_login)
    time.sleep(2)
    driver.implicitly_wait(10)
    print("Ok")
   #print("Realizando Login...")
   #name = driver.find_element_by_name("Ecom_User_ID")
   #name.send_keys("jmelati")
   #print("Preenchimento de Login: Ok")
   #password = driver.find_element_by_name("Ecom_Password")
   #password.send_keys("D@0912emb56YdR10")
   #print("Preenchimento de Senha: Ok")
   #login_box = driver.find_element_by_class_name("send")
   #login_box.click()
   #print("Logon: Ok")
   #time.sleep(2)
   #driver.implicitly_wait(10)

def element_click_xpath(xpath):

    '''
    Esta função simula o click do mouse baseado no xpath do HTML.
    
    args:
    xpath: xpath do HTML.
    
    ''' 
    
    time.sleep(1)
    click_box = driver.find_element_by_xpath(xpath)
    click_box.click()
    driver.implicitly_wait(10)
    print("click ok")
    
def element_find_xpath(xpath):

    '''
    Esta função simula o click do mouse baseado no xpath do HTML.
    
    args:
    xpath: xpath do HTML.
    
    ''' 
    
    time.sleep(1)
    text = driver.find_element(by="xpath", value=xpath)
    driver.implicitly_wait(10)
    print("get text ok")
    return text.text

def filter_project(project):

    '''
    Esta função realiza o preenchimento da aba de filtro com o projeto da aeronave.
    
    args:
    project: E1 ou E2.
    
    '''  
    print("fill project")
    time.sleep(1)
    project_box = driver.find_element_by_xpath("//html/body/div[1]/main/div[2]/form/div/div[2]/input")
    
    project_box.send_keys(Keys.CONTROL + 'a', Keys.BACKSPACE) 
    
    project_box.send_keys(project)
    project_box.send_keys(Keys.RETURN)
    driver.implicitly_wait(10)
    print("ok")
    
def combinacao_3_caracteres(n):
    lista_caracteres = []
    for i in range(0,n,1):
        for j in range(0,n,1):
            for k in range(0,n,1):
                temp_name = (string.ascii_lowercase[i] + string.ascii_lowercase[j] + string.ascii_lowercase[k]) 
                lista_caracteres.append(temp_name)
    return lista_caracteres

def navegar_nas_paginas(texto, num_registros, df):
    for i in range(0,num_registros+1,20):
        print(i)
        url = "http://www.emigrazioneveneta.com/busca?searchword={}&searchphrase=all&limitstart={}".format(texto, i)
        driver.implicitly_wait(10)
        time.sleep(1)
        print(url)
        driver.get(url)
        df_temp = pd.read_html(driver.page_source)[0] #Pegar a table
        df = df.append(df_temp, ignore_index=True) #Atualizar df
    return df

# %%
df_table = pd.DataFrame(columns=['Sobrenome', 'Fonte', 'PROVINCIA', 'Comune',
                                 'DATA DE NASCIMENTO', 'Paternidade', 'Cônjuge',
                                 'Data deCasamento', 'MATRIMÔNIO','CHEGADA  AO BRASIL'])

download_path =  os.path.abspath(os.getcwd()) + r"\downloads\\" #Caminho da pasta de Download
url_login= "http://www.emigrazioneveneta.com/" #Login do EGS
backup_path = r"C:\Users\John Melati\Documents\GitHub\web_scraping_emigrazione_veneta\\"

try:
    driver = build_driver(download_path)
    login(driver, url_login)
    element_click_xpath("//html/body/div[1]/main/section[1]/div/div[2]/a") #Search Button
    
    lista_caracteres = combinacao_3_caracteres(2)
    for palavra in lista_caracteres:
        filter_project(palavra) #Filter Project

        texto = element_find_xpath("//html/body/div[1]/main/div[2]/form/p")
        if texto != "Nenhum resultado encontrado":
            print("Existem Registros")
            num_registros = int((element_find_xpath("//html/body/div[1]/main/div[2]/form/p")).split()[-1])
            print(num_registros)
            df_table = navegar_nas_paginas(palavra, num_registros, df_table)
            
        else:
            print("Vazio")
        
except Exception as i:
    driver.quit()
    print("Ocorreu uma exceção")  
    print(i)
    
time2=datetime.datetime.now()
print('Executado em: ',time2-time1)
# Out:
# Ligando o Chrome Remoto...
# C:\Users\JOHNME~1\AppData\Local\Temp/ipykernel_17020/2889883479.py:24: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\John Melati\Documents\GitHub\web_scraping_emigrazione_veneta\chromedriver.exe", options=options)
# Ok
# Entrando na página de login...
# Ok
# C:\Users\JOHNME~1\AppData\Local\Temp/ipykernel_17020/2889883479.py:68: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   click_box = driver.find_element_by_xpath(xpath)
# click ok
# fill project
# C:\Users\JOHNME~1\AppData\Local\Temp/ipykernel_17020/2889883479.py:100: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   project_box = driver.find_element_by_xpath("//html/body/div[1]/main/div[2]/form/div/div[2]/input")
# ok
# get text ok
# Vazio
# fill project
# ok
# get text ok
# Vazio
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 3
# 0
# http://www.emigrazioneveneta.com/busca?searchword=aba&searchphrase=all&limitstart=0
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 2
# 0
# http://www.emigrazioneveneta.com/busca?searchword=abb&searchphrase=all&limitstart=0
# fill project
# ok
# get text ok
# Vazio
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 51
# 0
# http://www.emigrazioneveneta.com/busca?searchword=bab&searchphrase=all&limitstart=0
# 20
# http://www.emigrazioneveneta.com/busca?searchword=bab&searchphrase=all&limitstart=20
# 40
# http://www.emigrazioneveneta.com/busca?searchword=bab&searchphrase=all&limitstart=40
# fill project
# ok
# get text ok
# Vazio
# fill project
# ok
# get text ok
# Vazio
# Executado em:  0:02:26.339628

# %%
df_table
# Out:
#                    Sobrenome  Fonte PROVINCIA                   Comune  \
# 0                Abari Paolo   R.P.       ---         Luogo Conosciuto
# 1                Abate Maria  R.Go.       ---  Informazioni Conosciute
# 2           Abatini Abbondio   R.P.        Pd         Luogo conosciuto
# 3              Abbiati Carlo   R.P.       ---         Luogo Conosciuto
# 4          Abbornelli Teresa   F.S.       ---         Luogo Conosciuto
# 5               Baba Candido   R.P.        Pn         Luogo Conosciuto
# 6          Babalfi Benedetto   R.P.       ---         Luogo Conosciuto
# 7            Babalfi Bortolo   R.P.       ---         Luogo Conosciuto
# 8              Babalfi Maria   R.P.       ---         Luogo Conosciuto
# 9             Babandi Emilia   F.S.       ---         Luogo Conosciuto
# 10       Babandi Tertulliano   R.P.       ---         Luogo Conosciuto
# 11             Babbini Luigi   R.P.       ---         Luogo Conosciuto
# 12             Babbini Mario   R.P.       ---         Luogo Conosciuto
# 13           Babetto Antonio   P.A.       ---         Luogo Conosciuto
# 14           Babetto Celeste   R.P.       ---         Luogo Conosciuto
# 15            Babetto Emilia   R.P.       ---         Luogo Conosciuto
# 16            Babetto Emilio   R.P.       ---         Luogo Conosciuto
# 17           Babetto Erminia   R.P.       ---         Luogo Conosciuto
# 18          Babetto Giordano   R.P.       ---         Luogo Conosciuto
# 19          Babetto Giovanni   R.P.       ---         Luogo Conosciuto
# 20          Babetto Giovanni   R.P.       ---         Luogo Conosciuto
# 21          Babetto Giovanni   R.P.       ---         Luogo Conosciuto
# 22          Babetto Girolamo   R.P.       ---         Luogo Conosciuto
# 23          Babetto Giuditta   R.P.       ---         Luogo Conosciuto
# 24          Babetto Giuditta   F.S.       ---         Luogo Conosciuto
# 25          Babetto Giuseppe   R.P.       ---         Luogo Conosciuto
# 26          Babetto Giuseppe   P.A.       ---         Luogo Conosciuto
# 27          Babetto Giuseppe   R.P.       ---         Luogo Conosciuto
# 28             Babetto Maria   F.S.       ---         Luogo Conosciuto
# 29           Babetto Martino   R.P.       ---         Luogo Conosciuto
# 30              Babetto Mois   R.P.       ---         Luogo Conosciuto
# 31             Babetto Sante   F.S.       ---         Luogo Conosciuto
# 32             Babetto Serio   R.P.       ---         Luogo Conosciuto
# 33          Babetto Vincenzo   R.P.        Pd         Luogo Conosciuto
# 34          Babetto Vittorio   R.P.       ---         Luogo Conosciuto
# 35          Babetto Vittorio   P.A.       ---         Luogo Conosciuto
# 36            Babice Matilde   R.P.       ---         Luogo Conosciuto
# 37            Babolin Albino   R.P.       ---                      ---
# 38            Babolin Angela   R.P.       ---                      ---
# 39           Babolin Antonio   P.A.       ---         Luogo Conosciuto
# 40           Babolin Bortolo   R.P.       ---         Luogo Conosciuto
# 41             Babolin Elena   R.P.       ---                      ---
# 42            Babolin Elvira   F.S.       ---         Luogo Conosciuto
# 43            Babolin Enrico   R.P.       ---         Luogo Conosciuto
# 44       Babolin Ermenegildo   R.P.       ---                      ---
# 45         Babolin Francesco   R.P.       ---         Luogo Conosciuto
# 46          Babolin Giovanna   R.P.       ---                      ---
# 47          Babolin Giuseppe   R.P.       ---         Luogo Conosciuto
# 48            Babolin Italia   F.S.       ---         Luogo Conosciuto
# 49             Babolin Luigi   R.P.       ---         Luogo Conosciuto
# 50  Babolin Mariano Gherardo   R.P.        Pd         Luogo Conosciuto
# 51            Babolin Natale   RGS1       ---         Luogo Conosciuto
# 52             Babolin Paola   R.P.       ---                      ---
# 53            Babolin Pietro   R.P.       ---         Luogo Conosciuto
# 54             Babolin Primo   R.P.       ---         Luogo Conosciuto
# 55          Babolin Riccardo   R.P.       ---         Luogo Conosciuto
#
#    DATA DE NASCIMENTO                        Paternidade  \
# 0          02-11-1887         di Antonio e Carraro Maria
# 1                1861                         di Antonio
# 2          30-07-1863                            di n.n.
# 3          29-04-1887         di Angelo e Pedruzzi Maria
# 4                1851                            di n.n.
# 5          09-01-1876         di Giacomo e Toppa Augusta
# 6          14-06-1847                            di n.n.
# 7          18-03-1876   di Benedetto e Coradin Catterina
# 8          21-08-1872   di Benedetto e Coradin Catterina
# 9                1856     di Domenico e Salvagnini Maria
# 10         20-07-1854       di Giacomo e Boscain Colomba
# 11         13-12-1874       di Giuseppe e Levada Antonia
# 12         25-04-1880       di Giuseppe e Levada Antonia
# 13         19-02-1891        di Giuseppe e Babetto Maria
# 14         28-05-1883        di Giuseppe e Babetto Maria
# 15         12-12-1889         di Giordano e Bordin Maria
# 16         09-05-1889        di Giuseppe e Babetto Maria
# 17         29-09-1892        di Giovanni e Peraro Amalia
# 18         27-10-1865         di Domenico e Lion Antonia
# 19         26-03-1891          di Vittorio e Cesaro Rosa
# 20         23-10-1884          di Sante e Mazzucato Ruth
# 21         16-05-1868         di Domenico e Lion Antonia
# 22         23-01-1874         di Domenico e Lion Antonia
# 23         14-09-1860      di Vincenzo e Fogarolo Teresa
# 24               1855        di Luigi e Quaggio Giovanna
# 25         30-10-1877         di Domenico e Lion Antonia
# 26         30-01-1858       di Vincenzo e Fogarolo Maria
# 27         25-10-1895        di Giovanni e Peraro Amalia
# 28         04-05-1888          di Vittorio e Cesaro Rosa
# 29         11-11-1887        di Giuseppe e Babetto Maria
# 30         19-01-1894        di Giovanni e Peraro Amalia
# 31         06-07-1850         di Domenico e Longhin Anna
# 32         31-05-1894         di Giordano e Bordin Maria
# 33         11-04-1822    di Francesco e Minozzi Giustina
# 34         26-04-1880         di Domenico e Lion Antonia
# 35         29-09-1864  di Giovanni e Giacomello Domenica
# 36               1856       di Angelo e Biscaro Giovanna
# 37                ---      di Francesco e Fabris Sabrina
# 38                ---      di Francesco e Fabris Sabrina
# 39         09-02-1847           di Amedeo e Zaffin Maria
# 40         25-08-1883           di Natale e Conte Regina
# 41                ---      di Francesco e Fabris Sabrina
# 42         25-04-1884  di Antonio e Piazzon Maria Luigia
# 43         15-07-1895      di Francesco e Fabris Sabrina
# 44                ---      di Francesco e Fabris Sabrina
# 45         13-10-1857      di Agostino e Fabris Giovanna
# 46                ---      di Francesco e Fabris Sabrina
# 47         06-05-1871  di Antonio e Piazzon Maria Luigia
# 48         08-09-1888  di Antonio e Piazzon Maria Luigia
# 49         20-04-1876  di Antonio e Piazzon Maria Luigia
# 50         24-09-1875         di Agostino e Frigo Angela
# 51         25-12-1851       di Antonio e Romano Costanza
# 52               1834                                ---
# 53         09-08-1881  di Antonio e Piazzon Maria Luigia
# 54         02-04-1884      di Francesco e Fabris Sabrina
# 55         15-05-1897      di Francesco e Fabris Sabrina
#
#                  Cônjuge Data deCasamento        MATRIMÔNIO  \
# 0                    ---              ---               ---
# 1       Ferarin Giuseppe              ---               ---
# 2                    ---              ---               ---
# 3                    ---              ---               ---
# 4       Brugnaro Gaetano       30-11-1874  Luogo Conosciuto
# 5                    ---              ---               ---
# 6      Coradin Catterina       24-11-1870  Luogo Conosciuto
# 7                    ---              ---               ---
# 8                    ---              ---               ---
# 9    Meneghesso Vincenzo       20-08-1876  Luogo Conosciuto
# 10                   ---              ---               ---
# 11                   ---              ---               ---
# 12                   ---              ---               ---
# 13                   ---              ---               ---
# 14                   ---              ---               ---
# 15                   ---              ---               ---
# 16                   ---              ---               ---
# 17                   ---              ---               ---
# 18          Bordin Maria       02-02-1890  Luogo Conosciuto
# 19                   ---              ---               ---
# 20                   ---              ---               ---
# 21         Peraro Amalia       24-01-1893  Luogo Conosciuto
# 22                   ---              ---               ---
# 23       Foralosso Luigi       08-06-1879  Luogo Conosciuto
# 24      Zaggia Gio Batta       20-02-1881  Luogo Conosciuto
# 25                   ---              ---               ---
# 26                   ---              ---               ---
# 27                   ---              ---               ---
# 28                   ---              ---               ---
# 29                   ---              ---               ---
# 30                   ---              ---               ---
# 31        Mazzucato Ruth       23-03-1884  Luogo Conosciuto
# 32                   ---              ---               ---
# 33  ved. Fogarolo Teresa              ---               ---
# 34                   ---              ---               ---
# 35           Cesaro Rosa       30-11-1884  Luogo Conosciuto
# 36    Regalin Spiridione       20-06-1880  Luogo Conosciuto
# 37                   ---              ---               ---
# 38                   ---              ---               ---
# 39  Piazzon Maria Luigia              ---               ---
# 40                   ---              ---               ---
# 41                   ---              ---               ---
# 42                   ---              ---               ---
# 43                   ---              ---               ---
# 44                   ---              ---               ---
# 45         Fabris Sabina       19-03-1884               ---
# 46                   ---              ---               ---
# 47                   ---              ---               ---
# 48                   ---              ---               ---
# 49                   ---              ---               ---
# 50                   ---              ---               ---
# 51                   ---              ---               ---
# 52          Favaro Luigi              ---               ---
# 53                   ---              ---               ---
# 54                   ---              ---               ---
# 55                   ---              ---               ---
#
#              CHEGADA  AO BRASIL
# 0                           ---
# 1          30-01-1896 S.Paolo *
# 2                           ---
# 3          20-11-1892 S.Paolo *
# 4          05-12-1888 S.Paolo *
# 5                           ---
# 6                          1877
# 7                           ---
# 8                           ---
# 9          19-07-1887 S.Paolo *
# 10         29-06-1891 S.Paolo *
# 11                          ---
# 12                          ---
# 13         03-01-1892 S.Paolo *
# 14         03-01-1892 S.Paolo *
# 15         14-05-1895 S.Paolo *
# 16         03-01-1892 S.Paolo *
# 17         15-07-1897 S.Paolo *
# 18         14-05-1895 S.Paolo *
# 19         10-05-1893 S.Paolo *
# 20                          ---
# 21         15-07-1897 S.Paolo *
# 22         15-07-1897 S.Paolo *
# 23    31-10-1888 Minas Gerais *
# 24  17-06-1891 Rio de Janeiro *
# 25                          ---
# 26  20-11-1891 Rio de Janeiro *
# 27         15-07-1897 S.Paolo *
# 28         10-05-1893 S.Paolo *
# 29         03-01-1892 S.Paolo *
# 30         15-07-1897 S.Paolo *
# 31                          ---
# 32         14-05-1895 S.Paolo *
# 33                          ---
# 34                          ---
# 35         10-05-1893 S.Paolo *
# 36  21-06-1891 Rio de Janeiro *
# 37         19-09-1898 S.Paolo *
# 38         19-09-1898 S.Paolo *
# 39         05-12-1888 S.Paolo *
# 40                          ---
# 41         19-09-1898 S.Paolo *
# 42         05-12-1888 S.Paolo *
# 43         19-09-1898 S.Paolo *
# 44         19-09-1898 S.Paolo *
# 45         19-09-1898 S.Paolo *
# 46         19-09-1898 S.Paolo *
# 47         05-12-1888 S.Paolo *
# 48         05-12-1888 S.Paolo *
# 49         05-12-1888 S.Paolo *
# 50         07-04-1892 S.Paolo *
# 51                          ---
# 52  24-12-1888 Rio de Janeiro *
# 53         05-12-1888 S.Paolo *
# 54         19-09-1898 S.Paolo *
# 55         19-09-1898 S.Paolo *

# %%
def create_df(csv_file_path):
        
    '''
    Esta função realiza a criação e atualização do DataFrame.
    
    args:
    csv_file: csv_file
    
    '''
    time.sleep(1)
    
    df_csv = pd.read_csv(csv_file_path)
    
    if "EGS_Export.xlsx" in os.listdir("."):
        print("Atualizando arquivo...")
        df_egs = pd.read_excel("EGS_Export.xlsx")
        df_egs = df_egs.append(df_csv, ignore_index=True)
        df_egs.drop_duplicates(inplace=True)
        df_egs.to_excel("EGS_Export.xlsx", index=False)
        print("Ok")
    else:
        print("Criando arquivo...")
        df_egs = pd.DataFrame()
        df_egs = df_egs.append(df_csv, ignore_index=True)
        df_egs.drop_duplicates(inplace=True)
        df_egs.to_excel("EGS_Export.xlsx", index=False)
        print("Ok")
    return df_csv, df_egs

        
def save_df_to_backup_folder(df_egs, backup_path):
    '''
    Esta função realiza o backup (cópia) do arquivo para a pasta de backup.
    
    args:
    
    df_egs: dataframe
    backup_path: caminho onde encontra-se a pasta backup.
    
    '''
    print("saving backup")
    timestr = time.strftime("%Y_%m_%d-%H_%M_%S") 
    df_egs.to_excel(backup_path + f"df_egs_backup_{timestr}.xlsx", index=False)
    print("Ok")
