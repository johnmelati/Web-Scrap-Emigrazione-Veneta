# %%
#url: http://www.emigrazioneveneta.com/

# %%
## BIBLIOTECAS:
    # pip install requests2
    # pip install pandas
    # pip install lxml
    # pip install beautifulsoup4
    # pip install selenium

import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options
import os
import datetime
import time
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import string

time1=datetime.datetime.now()

# %%
def build_driver(download_path): 
    
    '''
    Esta função inicializa o webdriver incluindo as preferências.
    
    args:
    download_path: diretório da pasta de download.
    
    '''

    print("Ligando o Chrome Remoto...")
    option = Options()
    option.headless = True
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized") #Maximizar
    prefs = {"profile.default_content_settings.popups": 0,
             "download.default_directory": download_path, # Importante-Finalizar com barra dupla
             "download.prompt_for_download": False,
             "directory_upgrade": True,
             "safebrowsing.enabled": True}
    options.add_experimental_option("prefs", prefs)
    #driver=webdriver.Firefox()
    #driver = webdriver.Chrome(options=options)
    driver = webdriver.Chrome(r"C:\Users\John Melati\Documents\GitHub\web_scraping_emigrazione_veneta\chromedriver.exe", options=options)
    print("Ok")
    return driver

def login(driver, url_login): 
    
    '''
    Esta função realiza o login no site.
    
    args:
    driver: webdriver.
    url_login: url do site.
    
    '''

    print("Entrando na página de login...")
    driver.get(url_login)
    time.sleep(2)
    driver.implicitly_wait(10)
    print("Ok")
   #print("Realizando Login...")
   #name = driver.find_element_by_name("Ecom_User_ID")
   #name.send_keys("jmelati")
   #print("Preenchimento de Login: Ok")
   #password = driver.find_element_by_name("Ecom_Password")
   #password.send_keys("D@0912emb56YdR10")
   #print("Preenchimento de Senha: Ok")
   #login_box = driver.find_element_by_class_name("send")
   #login_box.click()
   #print("Logon: Ok")
   #time.sleep(2)
   #driver.implicitly_wait(10)

def element_click_xpath(xpath):

    '''
    Esta função simula o click do mouse baseado no xpath do HTML.
    
    args:
    xpath: xpath do HTML.
    
    ''' 
    
    time.sleep(1)
    click_box = driver.find_element_by_xpath(xpath)
    click_box.click()
    driver.implicitly_wait(10)
    print("click ok")
    
def element_find_xpath(xpath):

    '''
    Esta função simula o click do mouse baseado no xpath do HTML.
    
    args:
    xpath: xpath do HTML.
    
    ''' 
    
    time.sleep(1)
    text = driver.find_element(by="xpath", value=xpath)
    driver.implicitly_wait(10)
    print("get text ok")
    return text.text

def filter_project(project):

    '''
    Esta função realiza o preenchimento da aba de filtro com o projeto da aeronave.
    
    args:
    project: E1 ou E2.
    
    '''  
    print("fill project")
    time.sleep(1)
    project_box = driver.find_element_by_xpath("//html/body/div[1]/main/div[2]/form/div/div[2]/input")
    
    project_box.send_keys(Keys.CONTROL + 'a', Keys.BACKSPACE) 
    
    project_box.send_keys(project)
    project_box.send_keys(Keys.RETURN)
    driver.implicitly_wait(10)
    print("ok")
    
def combinacao_3_caracteres(n):
    lista_caracteres = []
    for i in range(1,2,1):
        for j in range(0,n,1):
            for k in range(0,n,1):
                temp_name = (string.ascii_lowercase[i] + string.ascii_lowercase[j] + string.ascii_lowercase[k]) 
                lista_caracteres.append(temp_name)
    return lista_caracteres

def navegar_nas_paginas(texto, num_registros, df):
    for i in range(0,num_registros+1,20):
        print(i)
        url = "http://www.emigrazioneveneta.com/busca?searchword={}&searchphrase=all&limitstart={}".format(texto, i)
        driver.implicitly_wait(10)
        time.sleep(1)
        print(url)
        driver.get(url)
        df_temp = pd.read_html(driver.page_source)[0] #Pegar a table
        df = df.append(df_temp, ignore_index=True) #Atualizar df
    return df

# %%
def combinacao_3_caracteres(n):
    lista_caracteres = []
    for i in range(1,2,1):
        for j in range(0,n,1):
            for k in range(0,n,1):
                temp_name = (string.ascii_lowercase[i] + string.ascii_lowercase[j] + string.ascii_lowercase[k]) 
                lista_caracteres.append(temp_name)
    return lista_caracteres
combinacao_3_caracteres(26)
# Out:
# ['baa',
#  'bab',
#  'bac',
#  'bad',
#  'bae',
#  'baf',
#  'bag',
#  'bah',
#  'bai',
#  'baj',
#  'bak',
#  'bal',
#  'bam',
#  'ban',
#  'bao',
#  'bap',
#  'baq',
#  'bar',
#  'bas',
#  'bat',
#  'bau',
#  'bav',
#  'baw',
#  'bax',
#  'bay',
#  'baz',
#  'bba',
#  'bbb',
#  'bbc',
#  'bbd',
#  'bbe',
#  'bbf',
#  'bbg',
#  'bbh',
#  'bbi',
#  'bbj',
#  'bbk',
#  'bbl',
#  'bbm',
#  'bbn',
#  'bbo',
#  'bbp',
#  'bbq',
#  'bbr',
#  'bbs',
#  'bbt',
#  'bbu',
#  'bbv',
#  'bbw',
#  'bbx',
#  'bby',
#  'bbz',
#  'bca',
#  'bcb',
#  'bcc',
#  'bcd',
#  'bce',
#  'bcf',
#  'bcg',
#  'bch',
#  'bci',
#  'bcj',
#  'bck',
#  'bcl',
#  'bcm',
#  'bcn',
#  'bco',
#  'bcp',
#  'bcq',
#  'bcr',
#  'bcs',
#  'bct',
#  'bcu',
#  'bcv',
#  'bcw',
#  'bcx',
#  'bcy',
#  'bcz',
#  'bda',
#  'bdb',
#  'bdc',
#  'bdd',
#  'bde',
#  'bdf',
#  'bdg',
#  'bdh',
#  'bdi',
#  'bdj',
#  'bdk',
#  'bdl',
#  'bdm',
#  'bdn',
#  'bdo',
#  'bdp',
#  'bdq',
#  'bdr',
#  'bds',
#  'bdt',
#  'bdu',
#  'bdv',
#  'bdw',
#  'bdx',
#  'bdy',
#  'bdz',
#  'bea',
#  'beb',
#  'bec',
#  'bed',
#  'bee',
#  'bef',
#  'beg',
#  'beh',
#  'bei',
#  'bej',
#  'bek',
#  'bel',
#  'bem',
#  'ben',
#  'beo',
#  'bep',
#  'beq',
#  'ber',
#  'bes',
#  'bet',
#  'beu',
#  'bev',
#  'bew',
#  'bex',
#  'bey',
#  'bez',
#  'bfa',
#  'bfb',
#  'bfc',
#  'bfd',
#  'bfe',
#  'bff',
#  'bfg',
#  'bfh',
#  'bfi',
#  'bfj',
#  'bfk',
#  'bfl',
#  'bfm',
#  'bfn',
#  'bfo',
#  'bfp',
#  'bfq',
#  'bfr',
#  'bfs',
#  'bft',
#  'bfu',
#  'bfv',
#  'bfw',
#  'bfx',
#  'bfy',
#  'bfz',
#  'bga',
#  'bgb',
#  'bgc',
#  'bgd',
#  'bge',
#  'bgf',
#  'bgg',
#  'bgh',
#  'bgi',
#  'bgj',
#  'bgk',
#  'bgl',
#  'bgm',
#  'bgn',
#  'bgo',
#  'bgp',
#  'bgq',
#  'bgr',
#  'bgs',
#  'bgt',
#  'bgu',
#  'bgv',
#  'bgw',
#  'bgx',
#  'bgy',
#  'bgz',
#  'bha',
#  'bhb',
#  'bhc',
#  'bhd',
#  'bhe',
#  'bhf',
#  'bhg',
#  'bhh',
#  'bhi',
#  'bhj',
#  'bhk',
#  'bhl',
#  'bhm',
#  'bhn',
#  'bho',
#  'bhp',
#  'bhq',
#  'bhr',
#  'bhs',
#  'bht',
#  'bhu',
#  'bhv',
#  'bhw',
#  'bhx',
#  'bhy',
#  'bhz',
#  'bia',
#  'bib',
#  'bic',
#  'bid',
#  'bie',
#  'bif',
#  'big',
#  'bih',
#  'bii',
#  'bij',
#  'bik',
#  'bil',
#  'bim',
#  'bin',
#  'bio',
#  'bip',
#  'biq',
#  'bir',
#  'bis',
#  'bit',
#  'biu',
#  'biv',
#  'biw',
#  'bix',
#  'biy',
#  'biz',
#  'bja',
#  'bjb',
#  'bjc',
#  'bjd',
#  'bje',
#  'bjf',
#  'bjg',
#  'bjh',
#  'bji',
#  'bjj',
#  'bjk',
#  'bjl',
#  'bjm',
#  'bjn',
#  'bjo',
#  'bjp',
#  'bjq',
#  'bjr',
#  'bjs',
#  'bjt',
#  'bju',
#  'bjv',
#  'bjw',
#  'bjx',
#  'bjy',
#  'bjz',
#  'bka',
#  'bkb',
#  'bkc',
#  'bkd',
#  'bke',
#  'bkf',
#  'bkg',
#  'bkh',
#  'bki',
#  'bkj',
#  'bkk',
#  'bkl',
#  'bkm',
#  'bkn',
#  'bko',
#  'bkp',
#  'bkq',
#  'bkr',
#  'bks',
#  'bkt',
#  'bku',
#  'bkv',
#  'bkw',
#  'bkx',
#  'bky',
#  'bkz',
#  'bla',
#  'blb',
#  'blc',
#  'bld',
#  'ble',
#  'blf',
#  'blg',
#  'blh',
#  'bli',
#  'blj',
#  'blk',
#  'bll',
#  'blm',
#  'bln',
#  'blo',
#  'blp',
#  'blq',
#  'blr',
#  'bls',
#  'blt',
#  'blu',
#  'blv',
#  'blw',
#  'blx',
#  'bly',
#  'blz',
#  'bma',
#  'bmb',
#  'bmc',
#  'bmd',
#  'bme',
#  'bmf',
#  'bmg',
#  'bmh',
#  'bmi',
#  'bmj',
#  'bmk',
#  'bml',
#  'bmm',
#  'bmn',
#  'bmo',
#  'bmp',
#  'bmq',
#  'bmr',
#  'bms',
#  'bmt',
#  'bmu',
#  'bmv',
#  'bmw',
#  'bmx',
#  'bmy',
#  'bmz',
#  'bna',
#  'bnb',
#  'bnc',
#  'bnd',
#  'bne',
#  'bnf',
#  'bng',
#  'bnh',
#  'bni',
#  'bnj',
#  'bnk',
#  'bnl',
#  'bnm',
#  'bnn',
#  'bno',
#  'bnp',
#  'bnq',
#  'bnr',
#  'bns',
#  'bnt',
#  'bnu',
#  'bnv',
#  'bnw',
#  'bnx',
#  'bny',
#  'bnz',
#  'boa',
#  'bob',
#  'boc',
#  'bod',
#  'boe',
#  'bof',
#  'bog',
#  'boh',
#  'boi',
#  'boj',
#  'bok',
#  'bol',
#  'bom',
#  'bon',
#  'boo',
#  'bop',
#  'boq',
#  'bor',
#  'bos',
#  'bot',
#  'bou',
#  'bov',
#  'bow',
#  'box',
#  'boy',
#  'boz',
#  'bpa',
#  'bpb',
#  'bpc',
#  'bpd',
#  'bpe',
#  'bpf',
#  'bpg',
#  'bph',
#  'bpi',
#  'bpj',
#  'bpk',
#  'bpl',
#  'bpm',
#  'bpn',
#  'bpo',
#  'bpp',
#  'bpq',
#  'bpr',
#  'bps',
#  'bpt',
#  'bpu',
#  'bpv',
#  'bpw',
#  'bpx',
#  'bpy',
#  'bpz',
#  'bqa',
#  'bqb',
#  'bqc',
#  'bqd',
#  'bqe',
#  'bqf',
#  'bqg',
#  'bqh',
#  'bqi',
#  'bqj',
#  'bqk',
#  'bql',
#  'bqm',
#  'bqn',
#  'bqo',
#  'bqp',
#  'bqq',
#  'bqr',
#  'bqs',
#  'bqt',
#  'bqu',
#  'bqv',
#  'bqw',
#  'bqx',
#  'bqy',
#  'bqz',
#  'bra',
#  'brb',
#  'brc',
#  'brd',
#  'bre',
#  'brf',
#  'brg',
#  'brh',
#  'bri',
#  'brj',
#  'brk',
#  'brl',
#  'brm',
#  'brn',
#  'bro',
#  'brp',
#  'brq',
#  'brr',
#  'brs',
#  'brt',
#  'bru',
#  'brv',
#  'brw',
#  'brx',
#  'bry',
#  'brz',
#  'bsa',
#  'bsb',
#  'bsc',
#  'bsd',
#  'bse',
#  'bsf',
#  'bsg',
#  'bsh',
#  'bsi',
#  'bsj',
#  'bsk',
#  'bsl',
#  'bsm',
#  'bsn',
#  'bso',
#  'bsp',
#  'bsq',
#  'bsr',
#  'bss',
#  'bst',
#  'bsu',
#  'bsv',
#  'bsw',
#  'bsx',
#  'bsy',
#  'bsz',
#  'bta',
#  'btb',
#  'btc',
#  'btd',
#  'bte',
#  'btf',
#  'btg',
#  'bth',
#  'bti',
#  'btj',
#  'btk',
#  'btl',
#  'btm',
#  'btn',
#  'bto',
#  'btp',
#  'btq',
#  'btr',
#  'bts',
#  'btt',
#  'btu',
#  'btv',
#  'btw',
#  'btx',
#  'bty',
#  'btz',
#  'bua',
#  'bub',
#  'buc',
#  'bud',
#  'bue',
#  'buf',
#  'bug',
#  'buh',
#  'bui',
#  'buj',
#  'buk',
#  'bul',
#  'bum',
#  'bun',
#  'buo',
#  'bup',
#  'buq',
#  'bur',
#  'bus',
#  'but',
#  'buu',
#  'buv',
#  'buw',
#  'bux',
#  'buy',
#  'buz',
#  'bva',
#  'bvb',
#  'bvc',
#  'bvd',
#  'bve',
#  'bvf',
#  'bvg',
#  'bvh',
#  'bvi',
#  'bvj',
#  'bvk',
#  'bvl',
#  'bvm',
#  'bvn',
#  'bvo',
#  'bvp',
#  'bvq',
#  'bvr',
#  'bvs',
#  'bvt',
#  'bvu',
#  'bvv',
#  'bvw',
#  'bvx',
#  'bvy',
#  'bvz',
#  'bwa',
#  'bwb',
#  'bwc',
#  'bwd',
#  'bwe',
#  'bwf',
#  'bwg',
#  'bwh',
#  'bwi',
#  'bwj',
#  'bwk',
#  'bwl',
#  'bwm',
#  'bwn',
#  'bwo',
#  'bwp',
#  'bwq',
#  'bwr',
#  'bws',
#  'bwt',
#  'bwu',
#  'bwv',
#  'bww',
#  'bwx',
#  'bwy',
#  'bwz',
#  'bxa',
#  'bxb',
#  'bxc',
#  'bxd',
#  'bxe',
#  'bxf',
#  'bxg',
#  'bxh',
#  'bxi',
#  'bxj',
#  'bxk',
#  'bxl',
#  'bxm',
#  'bxn',
#  'bxo',
#  'bxp',
#  'bxq',
#  'bxr',
#  'bxs',
#  'bxt',
#  'bxu',
#  'bxv',
#  'bxw',
#  'bxx',
#  'bxy',
#  'bxz',
#  'bya',
#  'byb',
#  'byc',
#  'byd',
#  'bye',
#  'byf',
#  'byg',
#  'byh',
#  'byi',
#  'byj',
#  'byk',
#  'byl',
#  'bym',
#  'byn',
#  'byo',
#  'byp',
#  'byq',
#  'byr',
#  'bys',
#  'byt',
#  'byu',
#  'byv',
#  'byw',
#  'byx',
#  'byy',
#  'byz',
#  'bza',
#  'bzb',
#  'bzc',
#  'bzd',
#  'bze',
#  'bzf',
#  'bzg',
#  'bzh',
#  'bzi',
#  'bzj',
#  'bzk',
#  'bzl',
#  'bzm',
#  'bzn',
#  'bzo',
#  'bzp',
#  'bzq',
#  'bzr',
#  'bzs',
#  'bzt',
#  'bzu',
#  'bzv',
#  'bzw',
#  'bzx',
#  'bzy',
#  'bzz']

# %%
df_table = pd.DataFrame(columns=['Sobrenome', 'Fonte', 'PROVINCIA', 'Comune',
                                 'DATA DE NASCIMENTO', 'Paternidade', 'Cônjuge',
                                 'Data deCasamento', 'MATRIMÔNIO','CHEGADA  AO BRASIL'])

download_path =  os.path.abspath(os.getcwd()) + r"\downloads\\" #Caminho da pasta de Download
url_login= "http://www.emigrazioneveneta.com/" #Login do EGS
backup_path = r"C:\Users\John Melati\Documents\GitHub\web_scraping_emigrazione_veneta\\"

try:
    driver = build_driver(download_path)
    login(driver, url_login)
    element_click_xpath("//html/body/div[1]/main/section[1]/div/div[2]/a") #Search Button
    
    lista_caracteres = combinacao_3_caracteres(26)
    for palavra in lista_caracteres:
        filter_project(palavra) #Filter Project

        texto = element_find_xpath("//html/body/div[1]/main/div[2]/form/p")
        if texto != "Nenhum resultado encontrado":
            print("Existem Registros")
            num_registros = int((element_find_xpath("//html/body/div[1]/main/div[2]/form/p")).split()[-1])
            print(num_registros)
            df_table = navegar_nas_paginas(palavra, num_registros, df_table)
            
        else:
            print("Vazio")
        
except Exception as i:
    driver.quit()
    print("Ocorreu uma exceção")  
    print(i)
    
time2=datetime.datetime.now()
print('Executado em: ',time2-time1)
# Out:
# Ligando o Chrome Remoto...
# C:\Users\JOHNME~1\AppData\Local\Temp/ipykernel_7892/2950593069.py:24: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\John Melati\Documents\GitHub\web_scraping_emigrazione_veneta\chromedriver.exe", options=options)
# Ok
# Entrando na página de login...
# Ok
# C:\Users\JOHNME~1\AppData\Local\Temp/ipykernel_7892/2950593069.py:68: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   click_box = driver.find_element_by_xpath(xpath)
# click ok
# fill project
# C:\Users\JOHNME~1\AppData\Local\Temp/ipykernel_7892/2950593069.py:100: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   project_box = driver.find_element_by_xpath("//html/body/div[1]/main/div[2]/form/div/div[2]/input")
# ok
# get text ok
# Vazio
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 51
# 0
# http://www.emigrazioneveneta.com/busca?searchword=bab&searchphrase=all&limitstart=0
# 20
# http://www.emigrazioneveneta.com/busca?searchword=bab&searchphrase=all&limitstart=20
# 40
# http://www.emigrazioneveneta.com/busca?searchword=bab&searchphrase=all&limitstart=40
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 321
# 0
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=0
# 20
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=20
# 40
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=40
# 60
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=60
# 80
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=80
# 100
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=100
# 120
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=120
# 140
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=140
# 160
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=160
# 180
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=180
# 200
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=200
# 220
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=220
# 240
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=240
# 260
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=260
# 280
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=280
# 300
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=300
# 320
# http://www.emigrazioneveneta.com/busca?searchword=bac&searchphrase=all&limitstart=320
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 87
# 0
# http://www.emigrazioneveneta.com/busca?searchword=bad&searchphrase=all&limitstart=0
# 20
# http://www.emigrazioneveneta.com/busca?searchword=bad&searchphrase=all&limitstart=20
# 40
# http://www.emigrazioneveneta.com/busca?searchword=bad&searchphrase=all&limitstart=40
# 60
# http://www.emigrazioneveneta.com/busca?searchword=bad&searchphrase=all&limitstart=60
# 80
# http://www.emigrazioneveneta.com/busca?searchword=bad&searchphrase=all&limitstart=80
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 44
# 0
# http://www.emigrazioneveneta.com/busca?searchword=bae&searchphrase=all&limitstart=0
# 20
# http://www.emigrazioneveneta.com/busca?searchword=bae&searchphrase=all&limitstart=20
# 40
# http://www.emigrazioneveneta.com/busca?searchword=bae&searchphrase=all&limitstart=40
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 17
# 0
# http://www.emigrazioneveneta.com/busca?searchword=baf&searchphrase=all&limitstart=0
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 321
# 0
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=0
# 20
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=20
# 40
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=40
# 60
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=60
# 80
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=80
# 100
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=100
# 120
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=120
# 140
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=140
# 160
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=160
# 180
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=180
# 200
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=200
# 220
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=220
# 240
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=240
# 260
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=260
# 280
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=280
# 300
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=300
# 320
# http://www.emigrazioneveneta.com/busca?searchword=bag&searchphrase=all&limitstart=320
# fill project
# ok
# get text ok
# Vazio
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 76
# 0
# http://www.emigrazioneveneta.com/busca?searchword=bai&searchphrase=all&limitstart=0
# 20
# http://www.emigrazioneveneta.com/busca?searchword=bai&searchphrase=all&limitstart=20
# 40
# http://www.emigrazioneveneta.com/busca?searchword=bai&searchphrase=all&limitstart=40
# 60
# http://www.emigrazioneveneta.com/busca?searchword=bai&searchphrase=all&limitstart=60
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 3
# 0
# http://www.emigrazioneveneta.com/busca?searchword=baj&searchphrase=all&limitstart=0
# fill project
# ok
# get text ok
# Vazio
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 1013
# 0
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=0
# 20
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=20
# 40
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=40
# 60
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=60
# 80
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=80
# 100
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=100
# 120
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=120
# 140
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=140
# 160
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=160
# 180
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=180
# 200
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=200
# 220
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=220
# 240
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=240
# 260
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=260
# 280
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=280
# 300
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=300
# 320
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=320
# 340
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=340
# 360
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=360
# 380
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=380
# 400
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=400
# 420
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=420
# 440
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=440
# 460
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=460
# 480
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=480
# 500
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=500
# 520
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=520
# 540
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=540
# 560
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=560
# 580
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=580
# 600
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=600
# 620
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=620
# 640
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=640
# 660
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=660
# 680
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=680
# 700
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=700
# 720
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=720
# 740
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=740
# 760
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=760
# 780
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=780
# 800
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=800
# 820
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=820
# 840
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=840
# 860
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=860
# 880
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=880
# 900
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=900
# 920
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=920
# 940
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=940
# 960
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=960
# 980
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=980
# 1000
# http://www.emigrazioneveneta.com/busca?searchword=bal&searchphrase=all&limitstart=1000
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 5
# 0
# http://www.emigrazioneveneta.com/busca?searchword=bam&searchphrase=all&limitstart=0
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 132
# 0
# http://www.emigrazioneveneta.com/busca?searchword=ban&searchphrase=all&limitstart=0
# 20
# http://www.emigrazioneveneta.com/busca?searchword=ban&searchphrase=all&limitstart=20
# 40
# http://www.emigrazioneveneta.com/busca?searchword=ban&searchphrase=all&limitstart=40
# 60
# http://www.emigrazioneveneta.com/busca?searchword=ban&searchphrase=all&limitstart=60
# 80
# http://www.emigrazioneveneta.com/busca?searchword=ban&searchphrase=all&limitstart=80
# 100
# http://www.emigrazioneveneta.com/busca?searchword=ban&searchphrase=all&limitstart=100
# 120
# http://www.emigrazioneveneta.com/busca?searchword=ban&searchphrase=all&limitstart=120
# fill project
# ok
# get text ok
# Vazio
# fill project
# ok
# get text ok
# Vazio
# fill project
# ok
# get text ok
# Vazio
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 1727
# 0
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=0
# 20
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=20
# 40
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=40
# 60
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=60
# 80
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=80
# 100
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=100
# 120
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=120
# 140
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=140
# 160
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=160
# 180
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=180
# 200
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=200
# 220
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=220
# 240
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=240
# 260
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=260
# 280
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=280
# 300
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=300
# 320
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=320
# 340
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=340
# 360
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=360
# 380
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=380
# 400
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=400
# 420
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=420
# 440
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=440
# 460
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=460
# 480
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=480
# 500
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=500
# 520
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=520
# 540
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=540
# 560
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=560
# 580
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=580
# 600
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=600
# 620
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=620
# 640
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=640
# 660
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=660
# 680
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=680
# 700
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=700
# 720
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=720
# 740
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=740
# 760
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=760
# 780
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=780
# 800
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=800
# 820
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=820
# 840
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=840
# 860
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=860
# 880
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=880
# 900
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=900
# 920
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=920
# 940
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=940
# 960
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=960
# 980
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=980
# 1000
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1000
# 1020
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1020
# 1040
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1040
# 1060
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1060
# 1080
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1080
# 1100
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1100
# 1120
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1120
# 1140
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1140
# 1160
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1160
# 1180
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1180
# 1200
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1200
# 1220
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1220
# 1240
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1240
# 1260
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1260
# 1280
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1280
# 1300
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1300
# 1320
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1320
# 1340
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1340
# 1360
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1360
# 1380
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1380
# 1400
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1400
# 1420
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1420
# 1440
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1440
# 1460
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1460
# 1480
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1480
# 1500
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1500
# 1520
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1520
# 1540
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1540
# 1560
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1560
# 1580
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1580
# 1600
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1600
# 1620
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1620
# 1640
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1640
# 1660
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1660
# 1680
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1680
# 1700
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1700
# 1720
# http://www.emigrazioneveneta.com/busca?searchword=bar&searchphrase=all&limitstart=1720
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 864
# 0
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=0
# 20
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=20
# 40
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=40
# 60
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=60
# 80
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=80
# 100
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=100
# 120
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=120
# 140
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=140
# 160
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=160
# 180
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=180
# 200
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=200
# 220
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=220
# 240
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=240
# 260
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=260
# 280
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=280
# 300
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=300
# 320
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=320
# 340
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=340
# 360
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=360
# 380
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=380
# 400
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=400
# 420
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=420
# 440
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=440
# 460
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=460
# 480
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=480
# 500
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=500
# 520
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=520
# 540
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=540
# 560
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=560
# 580
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=580
# 600
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=600
# 620
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=620
# 640
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=640
# 660
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=660
# 680
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=680
# 700
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=700
# 720
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=720
# 740
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=740
# 760
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=760
# 780
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=780
# 800
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=800
# 820
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=820
# 840
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=840
# 860
# http://www.emigrazioneveneta.com/busca?searchword=bas&searchphrase=all&limitstart=860
# fill project
# ok
# get text ok
# Existem Registros
# get text ok
# 480
# 0
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=0
# 20
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=20
# 40
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=40
# 60
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=60
# 80
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=80
# 100
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=100
# 120
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=120
# 140
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=140
# 160
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=160
# 180
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=180
# 200
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=200
# 220
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=220
# 240
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=240
# 260
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=260
# 280
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=280
# 300
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=300
# 320
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=320
# 340
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=340
# 360
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=360
# 380
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=380
# 400
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=400
# 420
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=420
# 440
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=440
# 460
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=460
# 480
# http://www.emigrazioneveneta.com/busca?searchword=bat&searchphrase=all&limitstart=480
# Ocorreu uma exceção
# No tables found
# Executado em:  3:02:02.373854

# %%
df_table
# Out:
#               Sobrenome  Fonte PROVINCIA                   Comune  \
# 0          Baba Candido   R.P.        Pn         Luogo Conosciuto
# 1     Babalfi Benedetto   R.P.       ---         Luogo Conosciuto
# 2       Babalfi Bortolo   R.P.       ---         Luogo Conosciuto
# 3         Babalfi Maria   R.P.       ---         Luogo Conosciuto
# 4        Babandi Emilia   F.S.       ---         Luogo Conosciuto
# ...                 ...    ...       ...                      ...
# 4656    Baston Giovanni   R.P.       ---         Luogo Conosciuto
# 4657    Baston Giuseppe   R.P.       ---         Luogo Conosciuto
# 4658       Baston Luigi   R.P.       ---         Luogo Conosciuto
# 4659       Baston Luigi   R.P.       ---         Luogo Conosciuto
# 4660      Bastoni Tosca  R.Go.       ---  Informazioni Conosciute
#
#      DATA DE NASCIMENTO                          Paternidade  \
# 0            09-01-1876           di Giacomo e Toppa Augusta
# 1            14-06-1847                              di n.n.
# 2            18-03-1876     di Benedetto e Coradin Catterina
# 3            21-08-1872     di Benedetto e Coradin Catterina
# 4                  1856       di Domenico e Salvagnini Maria
# ...                 ...                                  ...
# 4656         13-04-1885             di Luigi e Sandrin Maria
# 4657         01-10-1879            di Matteo e Soncin Angela
# 4658         04-04-1873        di Gio Batta e Rinaldi Luigia
# 4659         22-03-1860  di Giovanni e Scarabottolo Domenica
# 4660               1864                              di n.n.
#
#                   Cônjuge Data deCasamento        MATRIMÔNIO  \
# 0                     ---              ---               ---
# 1       Coradin Catterina       24-11-1870  Luogo Conosciuto
# 2                     ---              ---               ---
# 3                     ---              ---               ---
# 4     Meneghesso Vincenzo       20-08-1876  Luogo Conosciuto
# ...                   ...              ...               ...
# 4656                  ---              ---               ---
# 4657                  ---              ---               ---
# 4658                  ---              ---               ---
# 4659        Sandrin Maria       30-03-1884  Luogo Conosciuto
# 4660                  ---              ---               ---
#
#                CHEGADA  AO BRASIL
# 0                             ---
# 1                            1877
# 2                             ---
# 3                             ---
# 4            19-07-1887 S.Paolo *
# ...                           ...
# 4656  18-06-1891 Rio de Janeiro *
# 4657                          ---
# 4658                          ---
# 4659  18-06-1891 Rio de Janeiro *
# 4660  03-06-1891 Rio de Janeiro *
#
# [4661 rows x 10 columns]

# %%
def save_df_to_folder(df, download_path):
    '''
    Esta função realiza o backup (cópia) do arquivo para a pasta de backup.
    
    args:
    
    df_egs: dataframe
    backup_path: caminho onde encontra-se a pasta backup.
    
    '''
    print("saving backup")
    timestr = time.strftime("%Y_%m_%d-%H_%M_%S") 
    df.to_excel(download_path + f"df_B_{timestr}.xlsx", index=False)
    print("Ok")
    
save_df_to_folder(df_table, download_path)
# Out:
# saving backup
# Ok
